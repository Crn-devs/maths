// %% [markdown]
// # This file will show extended Arithmetic in Go
//
// Examples in this file
//     1. Compute powers in Go
//     2. Law of exponents
//     3. Math Conceps in Go

// %% [markdown]
// # The Law of exponents
//     “When multiplying powers with the same base, add the exponents.”
//
//     3^3 x 3^8 = 3^11
//
//     3^3 x 4^5 = 3x3x3 x 4x4x4x4

// %%
import 	("github.com/janpfeifer/gonb/gonbui"
		"math"
		"fmt"
)

// %%
%%

x,y := 3.00, 3.00
result := math.Pow(x,y)
eq := fmt.Sprintf(`$ %v^%v = %v $`, x,y,result)

gonbui.DisplayMarkdown(eq)
// Out:
// $ 3^3 = 27 $
