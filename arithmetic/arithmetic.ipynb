// %% [markdown]
// # Basic Arithmetic in Go using latex for printing.

// %%
import 	"github.com/janpfeifer/gonb/gonbui"

// %%
// Addition
%%

	x, y := 5, 4
	result := 5 + 4

	eq := fmt.Sprintf("$%v + %v = %v$", x, y, result)

	gonbui.DisplayMarkdown(eq)
// Out:
// $5 + 4 = 9$

// %%
// Subtraction
%%

	x, y := 5, 4
	result := 5 - 4

	eq := fmt.Sprintf("$%v - %v = %v$", x, y, result)

	gonbui.DisplayMarkdown(eq)
// Out:
// $5 - 4 = 1$

// %%
// Multiplication
%%

	x, y := 5, 4
	result := 5 * 4

	// either use escape characters or `` for double escaping
	eq := fmt.Sprintf(`$ %v \times %v = %v$`, x, y, result)
	eq2 := fmt.Sprintf("$ %v \\times %v = %v$", x, y, result)


	gonbui.DisplayMarkdown(eq)
	gonbui.DisplayMarkdown(eq2)
// Out:
// $ 5 \times 4 = 20$
// $ 5 \times 4 = 20$

// %%
// Division
%%
x,y := 5.00,4.00
result := x/y

eq := fmt.Sprintf(`$ %v \div %v = %v$`, x, y, result)

gonbui.DisplayMarkdown(eq)
// Out:
// $ 5 \div 4 = 1.25$

// %%
// fractions
%%
x,y := 5.00,4.00
result := x/y

eq := fmt.Sprintf(`$ \frac{%v}{%v} = %v$`, x, y, result)

gonbui.DisplayMarkdown(eq)
// Out:
// $ \frac{5}{4} = 1.25$

// %%
// Algebra
%%
x,y := 7,-2

result := 3 * x * (4 + y)

eq := fmt.Sprintf(`$ 3x(4 + y) = %v$`, result)

gonbui.DisplayMarkdown(eq)
// Out:
// $ 3x(4 + y) = 42$

// %%
// Algebra
%%
x,y,z := 7,-2, 5

result := -y-(x+3)/z

eq := fmt.Sprintf(`$ -y-\frac{x + 3}{z} = %v$`, result)

gonbui.DisplayMarkdown(eq)
// Out:
// $ -y-\frac{x + 3}{z} = 0$
