# %% [markdown]
# # Absolute values in python

# %%
from IPython.display import display,Math

# %% [markdown]
# # Basic usage

# %%
a = -5
b = abs(a)
a,b
# Out:
# (-5, 5)

# %% [markdown]
# # What is an absolute value
#
# an absolute value is the non negative distance from zero on a number line
#
# for example if we have a line from -5 -> 5
#
# the absolute value of -5 is 5 due to -5 being 5 spaces from 0
#
# in math its represented as |-5| = 5

# %% [markdown]
# Exercise -> Print the absolute value of each number of a set of numbers only if each number is < -5 or < -5

# %%
import string


numbers = [-4,6,-1,43,-18,2,0]

for v in numbers:
    if v < -5 or v > 2:
        display(Math('absolute value of |%d| = %d' %(v, abs(v))))
    else:
        print(str(v), "was not tested")
# Out:
# -4 was not tested
# $\displaystyle absolute value of |6| = 6$
# -1 was not tested
# $\displaystyle absolute value of |43| = 43$
# $\displaystyle absolute value of |-18| = 18$
# 2 was not tested
# 0 was not tested
